# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('ticks', {"axes.linewidth": "1",'axes.yaxis.grid':False})

# %%
import numpy as np
# from phys.phys_utils import nnan_pearsonr as nnan_pearsonr
# from phys.plot_scripts import generic_plot_utils as rr_gpu
# from phys.plot_scripts import neural_behavioral_traces
from utils.phys_utils import nnan_pearsonr as nnan_pearsonr
from utils import generic_plot_utils as rr_gpu
from utils import neural_behavioral_traces

# %%
self = neural_behavioral_traces.PlotHelper(subject_id='perle_hand_dmfc')
self.load_data()
idx_to_plot = [305, 113] # np.argsort(-r_all)[50:60]

FR_embed = self.data_aug['neural_responses_reliable']['occ'][idx_to_plot]

for i in range(len(idx_to_plot)):
    data_fr = FR_embed[i]
    f,axes = plt.subplots(1,3,figsize=(10,3))
    ax = axes[0]
    time_ax, y_masked = self.plot_response_trace_over_time(ax, data_fr, 'start_occ_pad0', '-', realign_to_start=True)
    ax.set_yticks([])
    rr_gpu.make_axis_nice(ax)

    # print(time_ax)
    np.savetxt('%s_vis.csv'%(idx_to_plot[i]),y_masked, fmt='%5.3f', delimiter=',', newline='\n')

    ax = axes[1]
    time_ax, y_masked2 = self.plot_response_trace_over_time(ax, data_fr, 'occ_end_pad0', '-', realign_to_start=True)
    ax.set_yticks([])
    rr_gpu.make_axis_nice(ax)

    # print(time_ax)
    np.savetxt('%s_occ.csv'%(idx_to_plot[i]),y_masked2, fmt='%5.3f', delimiter=',', newline='\n')

    ax = axes[2]
    self.plot_response_over_2d_var_heatmap(data_fr, 'ball_pos_x_TRUE', 'ball_pos_y_TRUE',
                                           mask_fn='start_end_pad0', condition=self.condition, f=f, axes=ax)
    ax.set_axis_off()
    # f.savefig('%s/example_unit_%d.pdf' % (self.figoutpath, idx_to_plot[i]))

# %%
self2 = neural_behavioral_traces.PlotHelper(subject_id='mahler_hand_dmfc')
self2.load_data()
idx_to_plot = [39, 294] # np.argsort(-r_all)[50:60]

FR_embed = self2.data_aug['neural_responses_reliable']['occ'][idx_to_plot]

for i in range(len(idx_to_plot)):
    data_fr = FR_embed[i]
    f,axes = plt.subplots(1,3,figsize=(10,3))
    ax = axes[0]
    time_ax, y_masked = self2.plot_response_trace_over_time(ax, data_fr, 'start_occ_pad0', '-', realign_to_start=True)
    ax.set_yticks([])
    rr_gpu.make_axis_nice(ax)

    # print(time_ax)
    np.savetxt('%s_vis.csv'%(idx_to_plot[i]),y_masked, fmt='%5.3f', delimiter=',', newline='\n')

    ax = axes[1]
    time_ax, y_masked = self2.plot_response_trace_over_time(ax, data_fr, 'occ_end_pad0', '-', realign_to_start=True)
    ax.set_yticks([])
    rr_gpu.make_axis_nice(ax)

    # print(time_ax)
    np.savetxt('%s_occ.csv'%(idx_to_plot[i]),y_masked2, fmt='%5.3f', delimiter=',', newline='\n')

    ax = axes[2]
    self2.plot_response_over_2d_var_heatmap(data_fr, 'ball_pos_x_TRUE', 'ball_pos_y_TRUE',
                                           mask_fn='start_end_pad0', condition=self2.condition, f=f, axes=ax)
    ax.set_axis_off()
    # f.savefig('%s/example_unit_%d.pdf' % (self.figoutpath, idx_to_plot[i]))
