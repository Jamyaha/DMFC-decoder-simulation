# %%
import seaborn as sns
sns.set_style('ticks', {"axes.linewidth": "1",'axes.yaxis.grid':False})
import numpy as np
from importlib import reload

# from phys.plot_scripts import rnn_comparisons_2021 as rnn_plots
from utils.plot_scripts import rnn_comparisons_2021 as rnn_plots

# %%
# reload(rnn_plots)

# %%
ph = rnn_plots.PlotHelper(subject_id='all_hand_dmfc')
self = ph
self.load_data()
self.set_prefs()

# %%
self.plot_bar_rsquared()

# %%
self.plot_consistency_over_groups()
# Y: neural consistency score = 'pdist_similarity_start_end_pad0_%s_r_xy_n_sb' % self.disttype,
# X: mov=RNN_Intercept, vis-mov=RNN_Vis, vis-sim-mov=RNN_Vis+Occ, sim-mov=RNN_Vis&Occ

# %%
self.data_df.to_csv('all_neural_consistency_score.csv')

# %% [markdown]
# # perle

# %%
ph = rnn_plots.PlotHelper(subject_id='perle_hand_dmfc')
self = ph
self.load_data()
self.set_prefs()

# %%
self.plot_bar_rsquared()

# %%
self.plot_consistency_over_groups()
# Y: neural consistency score = 'pdist_similarity_occ_end_pad0_%s_r_xy_n_sb' % self.disttype,
# X: mov=RNN_Intercept, vis-mov=RNN_Vis, vis-sim-mov=RNN_Vis+Occ, sim-mov=RNN_Vis&Occ
# Out:
# /opt/anaconda3/envs/mworks/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
self.data_df.to_csv('perle_neural_consistency_score.csv')

# %%
self.plot_scatter_rsquared()
# Y: neural consistency score = 'pdist_similarity_occ_end_pad0_%s_r_xy_n_sb' % self.disttype,
# X: simulation index = 'decode_vis-sim_to_sim_index_mae_k2',
# X: task performance = 'error_f_mae'

# %% [markdown]
# # mahler

# %%
ph = rnn_plots.PlotHelper(subject_id='mahler_hand_dmfc')
self = ph
self.load_data()
self.set_prefs()

# %%
self.plot_bar_rsquared()

# %%
self.plot_consistency_over_groups()
# Y: neural consistency score = 'pdist_similarity_occ_end_pad0_%s_r_xy_n_sb' % self.disttype,
# X: mov=RNN_Intercept, vis-mov=RNN_Vis, vis-sim-mov=RNN_Vis+Occ, sim-mov=RNN_Vis&Occ
# Out:
# /opt/anaconda3/envs/mworks/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
self.data_df.to_csv('mahler_neural_consistency_score.csv')

# %%
self.plot_scatter_rsquared()
# Y: neural consistency score = 'pdist_similarity_occ_end_pad0_%s_r_xy_n_sb' % self.disttype,
# X: simulation index = 'decode_vis-sim_to_sim_index_mae_k2',
# X: task performance = 'error_f_mae'
