# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('ticks', {"axes.linewidth": "1",'axes.yaxis.grid':False})

# %%
from phys.phys_utils import nnan_pearsonr as nnan_pearsonr

# %%
import pickle as pk
import numpy as np
from phys.plot_scripts import generic_plot_utils as rr_gpu
from phys.plot_scripts.decoding_summary import PlotHelper

# %%
ph = PlotHelper(timebinsize=50,
                subject_id='all_hand_dmfc',
                masks_to_test_suffix='start_end_pad0',
                condition='occ',
                neural_data_to_use='neural_responses_reliable_FactorAnalysis_50',
                ncomp=50)

# %%
ph.load_data()
ph.load_ground_truth_data()
ph.get_colormap_for_decoded_variables()
# Out:
# /Users/hansem/Dropbox (MIT)/MPong/phys/results/old_from_rishi_om/decode_results//decode_all_hand_dmfc_occ_start_end_pad0_50ms_0.50_neural_responses_reliable_FactorAnalysis_50.pkl
# /opt/anaconda3/envs/mworks/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.2, the latest is 0.5.4.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
self = ph

# %%
# c = plt.cm.Greens()
plt.set_cmap('Greens')

# %%
self.dat['res_decode'][self.center_mask_idx].keys()
# Out:
# dict_keys(['unflatten_res', 'r_mu', 'r_sd', 'r_dist', 'rs_mu', 'rs_sd', 'rs_dist', 'mae_mu', 'mae_sd', 'mae_dist', 'y_pred_mu', 'y_pred_sd', 'y_pred_dist', 'y_true_mu', 'y_true_sd', 'y_true_dist'])

# %%
x = self.dat['res_decode'][self.center_mask_idx]['y_pred_dist'][0,:,1]
y = self.dat['res_decode'][self.center_mask_idx]['y_true_dist'][0,:,1]
r, p = nnan_pearsonr(x, y)
print(r, p)
# Out:
# 0.8327026440162769 0.0

# %%
self.plot_decode_performance_for_all_behvars()

# %%
self.plot_decode_performance_xy([0, 1])
# f, axes = plt.subplots(1, 1, gridspec_kw={'width_ratios': [1]}, figsize=(4, 4))
# time_idx = self.center_mask_idx
# ax = axes
#
# cols = [plt.cm.Dark2(1), plt.cm.Dark2(2)]
#
# for decode_var_idx in [1,0]:
#     x0 = self.dat['res_decode'][time_idx]['y_true_mu'][:, decode_var_idx]
#     y0 = self.dat['res_decode'][time_idx]['y_pred_mu'][:, decode_var_idx]
#     r_mu = self.dat['res_decode'][time_idx]['r_mu'][decode_var_idx]
#     r_sd = self.dat['res_decode'][time_idx]['r_sd'][decode_var_idx]
#     ax = sns.regplot(x=x0, y=y0, ax=ax, marker='.', color=cols[decode_var_idx],
#                      scatter_kws={'alpha':0.1}, line_kws={'linestyle':'--', 'color':'k', 'lw':1},
#                     label='$\it{r=%2.2f±%2.2f}$'%(r_mu, r_sd))
#
#
#
# #     ax.plot(x0, y0, '.', color=self.dec_cols['ball_var_idx'], alpha=0.2)
# # lims = [np.nanmin([x0, y0]), np.nanmax([x0, y0])]
# # ax.set_xlim(lims)
# # ax.set_ylim(lims)
# plt.legend()
# ax.set_xlabel('True')
# ax.set_ylabel('Predicted')
# rr_gpu.make_axis_nice(ax)
# file_suffix = ''
# outfn = '%s/%s_decbar_partial_beh_xydmask%d%s.pdf' % (self.figoutpath, self.save_prefix,
#                                                             time_idx, file_suffix)
# f.savefig(outfn)

# %%
self.plot_decode_performance_xy([6, 7])

# %%
self.plot_decode_performance_per_behvar_with_partial(0) # ball_pos_x_TRUE
self.plot_decode_performance_per_behvar_with_partial(1) # ball_pos_y_TRUE

# %%
self.plot_decode_performance_per_behvar_with_partial(6) # ball_pos_ego_x_TRUE
self.plot_decode_performance_per_behvar_with_partial(7) # ball_pos_ego_y_TRUE

# %%
self.plot_decode_performance_unrolled_over_time(compute_egocentric=False)
# Out:
# /Users/hansem/Dropbox (MIT)/MPong/phys/plot_scripts/decoding_summary.py:148: RuntimeWarning: Mean of empty slice
#   mae_t = np.nanmean(np.abs(x_cxt - y_cxt), axis=0)
# /Users/hansem/Dropbox (MIT)/MPong/phys/plot_scripts/decoding_summary.py:149: RuntimeWarning: Mean of empty slice
#   mse_t = np.nanmean((x_cxt - y_cxt) ** 2, axis=0)
# /opt/anaconda3/envs/mworks/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4427: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/hansem/Dropbox (MIT)/MPong/phys/plot_scripts/decoding_summary.py:540: RuntimeWarning: Mean of empty slice
#   mu.append(np.nanmean(x, axis=0))
# /opt/anaconda3/envs/mworks/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...

# %%
self.plot_decode_performance_unrolled_over_time(compute_egocentric=True)
# Out:
# /Users/hansem/Dropbox (MIT)/MPong/phys/plot_scripts/decoding_summary.py:148: RuntimeWarning: Mean of empty slice
#   mae_t = np.nanmean(np.abs(x_cxt - y_cxt), axis=0)
# /Users/hansem/Dropbox (MIT)/MPong/phys/plot_scripts/decoding_summary.py:149: RuntimeWarning: Mean of empty slice
#   mse_t = np.nanmean((x_cxt - y_cxt) ** 2, axis=0)
# /opt/anaconda3/envs/mworks/lib/python3.8/site-packages/scipy/stats/_stats_py.py:4427: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# /Users/hansem/Dropbox (MIT)/MPong/phys/plot_scripts/decoding_summary.py:540: RuntimeWarning: Mean of empty slice
#   mu.append(np.nanmean(x, axis=0))
# /opt/anaconda3/envs/mworks/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1872: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ...

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self.plot_decode_performance_for_all_behvars([0,1], file_suffix='ball_pos')

# %%
# self

# %%
# time_idx = self.center_mask_idx
#
# partial_corr_var_idx = [8, 9, 10, 11, 12, 13, 14, 15, 16, 6, 7]
#
# i1=0
#
# x0_all = self.dat['res_decode'][time_idx]['y_pred_dist'][:, :, i1]
# y0_all = self.dat['res_decode'][time_idx]['y_true_dist'][:, :, i1]
#
# r_raw_list = [nnan_pearsonr(x0, y0)[0] for x0, y0 in zip(x0_all, y0_all)]
